# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
dfCSV = pd.read_csv('/Users/simonkunitsyn/Desktop/Python/PythonPorjects/-VIS -Titanic/train.csv')

# %%
df = dfCSV.copy()

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
g = sns.catplot(x= "Survived", 
                hue = "Pclass", 
                aspect = 2,
                palette = "husl",
                kind = "count", 
                data = df)

g.set_xticklabels(["Yes", "No"])

# %%
#ax = plt.subplots(figsize=(10,15))

sns.lmplot(x = "PassengerId", 
                y = "Fare", 
                hue = "Sex",
                height= 8,
                data = df)

# %%
sns.jointplot(x = "Age", y = "Fare", hue = "Sex",kind = "kde",palette = "hsv", data = df)

# %%
ax = sns.catplot(x = "Pclass", 
            col= "Sex", 
            palette = "Set2",
            kind = "count", 
            height= 5,
            data = df)

ax.set_ylabels("Total Passengers")
ax.set_xlabels("Passanger class")
ax.set_xticklabels(["First", "Second", "Third"])

# %%
sns.displot(df, x="Age", kind = "kde", color = "green")

# %%
sns.displot(df, x= "Fare", hue = "Sex", color = "blue", kind = "kde")

# %%
sns.displot(df, x= "Fare", hue = "Pclass", color = "blue", kind = "kde")

# %%
plt.figure(figsize=(9,7))
ax = sns.heatmap(data = df.corr(), 
                 annot= True, 
                 linewidths=4, 
                 linecolor = "black", 
                 cmap = "plasma", 
                 vmin = -0.125, 
                 vmax = 1)

# %%
AgeDF = df["Age"]
SexDF = df["Sex"]
SexDF = pd.DataFrame(SexDF)
AgeDF = pd.DataFrame(AgeDF)
SexDF = pd.get_dummies(SexDF)
DFAS = pd.concat([SexDF,AgeDF], axis= 1)

# %%
dfName = df['Name'].copy()
dfName = pd.DataFrame(dfName)
dfName
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %% [markdown]
# ### TOP FREQUENT WORDS IN NAMES

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# %%
text = df["Name"].copy()
text = " ".join(i for i in text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="black").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
